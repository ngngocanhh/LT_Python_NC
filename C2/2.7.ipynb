# %%
import json

data = [
    {"id": 1, "name": "An", "unit": "A1"},
    {"id": 2, "name": "Binh", "unit": "A2"}
]

with open("sample.json", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Dữ liệu sau khi chuyển từ JSON sang Python:")
for du_lieu in data:
    print(du_lieu)
# Out:
# Dữ liệu sau khi chuyển từ JSON sang Python:
# {'id': 1, 'name': 'An', 'unit': 'A1'}
# {'id': 2, 'name': 'Binh', 'unit': 'A2'}
