# %%
import json

data = [
    {"id": 1, "name": "An", "unit": "A1"},
    {"id": 2, "name": "Bình", "unit": "A2"}
]

chuoi_json = json.dumps(data, ensure_ascii=False, indent=4)

print("Chuỗi JSON:")
print(chuoi_json)
# Out:
# Chuỗi JSON:
# [
#     {
#         "id": 1,
#         "name": "An",
#         "unit": "A1"
#     },
#     {
#         "id": 2,
#         "name": "Bình",
#         "unit": "A2"
#     }
# ]
