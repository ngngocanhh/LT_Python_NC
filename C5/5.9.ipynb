# %%
import pandas as pd

# 1. Tạo file CSV
df = pd.DataFrame({
    'REGION_ID': [1, 2, 3, 4],
    'REGION_NAME': ['Europe', 'Americas', 'Asia', 'Middle East and Africa']
})
df.to_csv('region.csv', index=False)

# 2. Hiển thị nội dung
print(pd.read_csv('region.csv'))
# Out:
#    REGION_ID             REGION_NAME
# 0          1                  Europe
# 1          2                Americas
# 2          3                    Asia
# 3          4  Middle East and Africa
