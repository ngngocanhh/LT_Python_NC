# %%
import sqlite3

conn = sqlite3.connect("example.db")
cursor = conn.cursor()

cursor.execute("""
UPDATE students
SET score = score + 1
""")

conn.commit()
print("Đã cập nhật điểm cho tất cả sinh viên")

conn.close()
# Out:
# Đã cập nhật điểm cho tất cả sinh viên
